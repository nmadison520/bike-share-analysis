# %% [markdown]
# # September 2
#     + Conditional Statements
#     + Conditional Operators
#     + Logical Operators
#     + Loops

# %% [markdown]
# #### Review % (mod) operator

# %% [markdown]
# #### Conditional Statements
